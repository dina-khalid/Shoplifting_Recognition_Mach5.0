# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# %%
import os
import cv2
import numpy as np
from PIL import Image
import torch
from torchvision.transforms import functional as F
import time

# Load yolov5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Define function to process videos in a folder
def process_videos(folder_path, class_label, output_folder):
    videos = os.listdir(folder_path)
    for video in videos:
        video_path = os.path.join(folder_path, video)
        cap = cv2.VideoCapture(video_path)

        # Get video properties
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fps = cap.get(cv2.CAP_PROP_FPS)

        # Define video writer
        output_path = os.path.join(output_folder, f'{class_label}_{video}')
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

        ret = True
        frame_count = 0
        start_time = time.time()

        while ret:
            ret, frame = cap.read()

            if ret:
                # Convert frame to PIL Image
                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                pil_image = Image.fromarray(frame)

                # Perform object detection
                results = model(pil_image)

                # Get bounding box coordinates and class labels
                bboxes = results.xyxy[0].cpu().numpy()
                labels = results.names[0]

                # Filter out non-person objects
                person_bboxes = []
                for bbox, label in zip(bboxes, labels):
                    if label == 'p':
                        person_bboxes.append(bbox)

                # Draw bounding boxes and labels on the frame for person objects only
                for bbox in person_bboxes:
                    x1, y1, x2, y2, conf, cls = bbox

                    # Draw bounding box and labels on the frame
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
                    cv2.putText(frame, 'p', (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

                # Write the frame to the output video
                out.write(frame)

                frame_count += 1
                if cv2.waitKey(25) & 0xFF == ord('q'):
                    break

        # Calculate FPS
        end_time = time.time()
        total_time = end_time - start_time
        fps = frame_count / total_time

        print(f"Processed {video}, FPS: {fps}")

        # Release the video capture and writer
        cap.release()
        out.release()

# Define paths for input and output folders
input_folder = '/content/drive/MyDrive/challenge_dataset'
output_folder = '/content/drive/MyDrive/processed_videos'

#Process videos in the train folder
train_lifting_folder = os.path.join(input_folder, 'train', '1_lifting')
train_no_lifting_folder = os.path.join(input_folder, 'train', '0_no_lifting')

train_lifting_output_folder = os.path.join(output_folder, 'train', '1_lifting')
train_no_lifting_output_folder = os.path.join(output_folder, 'train', '0_no_lifting')

os.makedirs(train_lifting_output_folder, exist_ok=True)
os.makedirs(train_no_lifting_output_folder, exist_ok=True)

process_videos(train_lifting_folder, '1_lifting', train_lifting_output_folder)
process_videos(train_no_lifting_folder, '0_no_lifting', train_no_lifting_output_folder)

#Process videos in the val folder
val_lifting_folder = os.path.join(input_folder, 'val', '1_lifting')
val_no_lifting_folder = os.path.join(input_folder, 'val', '0_no_lifting')

val_lifting_output_folder = os.path.join(output_folder, 'val', '1_lifting')
val_no_lifting_output_folder = os.path.join(output_folder, 'val', '0_no_lifting')

os.makedirs(val_lifting_output_folder, exist_ok=True)
os.makedirs(val_no_lifting_output_folder, exist_ok=True)

process_videos(val_lifting_folder, '1_lifting', val_lifting_output_folder)
process_videos(val_no_lifting_folder, '0_no_lifting', val_no_lifting_output_folder)

#Process videos in the test folder
test_lifting_folder = os.path.join(input_folder, 'test', '1_lifting')
test_no_lifting_folder = os.path.join(input_folder, 'test', '0_no_lifting')

test_lifting_output_folder = os.path.join(output_folder, 'test', '1_lifting')
test_no_lifting_output_folder = os.path.join(output_folder, 'test', '0_no_lifting')

os.makedirs(test_lifting_output_folder, exist_ok=True)
os.makedirs(test_no_lifting_output_folder, exist_ok=True)

process_videos(test_lifting_folder, '1_lifting', test_lifting_output_folder)
process_videos(test_no_lifting_folder, '0_no_lifting', test_no_lifting_output_folder)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024
# Processed shop_lifter_n_186.mp4, FPS: 73.45951902293916
# Processed shop_lifter_n_187.mp4, FPS: 54.82665279789124
# Processed shop_lifter_n_212.mp4, FPS: 72.36161246996119
# Processed shop_lifter_n_162.mp4, FPS: 75.02531965731977
# Processed shop_lifter_n_178.mp4, FPS: 65.06542592581758
# Processed shop_lifter_n_196.mp4, FPS: 73.60692580791171
# Processed shop_lifter_n_210.mp4, FPS: 62.83875070276468
# Processed shop_lifter_n_173.mp4, FPS: 72.65992350034645
# Processed shop_lifter_n_165.mp4, FPS: 62.99453944213923
# Processed shop_lifter_n_192.mp4, FPS: 74.14124105633857
# Processed shop_lifter_n_135.mp4, FPS: 67.24734801563046
# Processed shop_lifter_n_126.mp4, FPS: 61.06035248806541
# Processed shop_lifter_n_159.mp4, FPS: 74.6612008486385
# Processed shop_lifter_n_152.mp4, FPS: 61.67527022607223
# Processed shop_lifter_n_125.mp4, FPS: 73.35294866575165
# Processed shop_lifter_n_153.mp4, FPS: 72.2653426890968
# Processed shop_lifter_n_124.mp4, FPS: 53.08572590449451
# Processed shop_lifter_n_149.mp4, FPS: 71.23079845851014
# Processed shop_lifter_n_151.mp4, FPS: 72.78077628841852
# Processed shop_lifter_n_130.mp4, FPS: 65.85676359920538
# Processed shop_lifter_n_140.mp4, FPS: 62.98969604759006
# Processed shop_lifter_n_139.mp4, FPS: 73.20081800261023
# Processed shop_lifter_n_131.mp4, FPS: 59.45180256462693
# Processed shop_lifter_n_119.mp4, FPS: 71.59725343208326
# Processed shop_lifter_n_155.mp4, FPS: 71.78272079305361
# Processed shop_lifter_n_117.mp4, FPS: 68.88533787528277
# Processed shop_lifter_n_148.mp4, FPS: 58.5966021686939
# Processed shop_lifter_n_147.mp4, FPS: 70.12284665210761
# Processed shop_lifter_n_158.mp4, FPS: 65.86050017272603
# Processed shop_lifter_n_138.mp4, FPS: 61.4354850590792
# Processed shop_lifter_n_123.mp4, FPS: 70.21042937663299
# Processed shop_lifter_n_127.mp4, FPS: 67.05296328556808
# Processed shop_lifter_n_142.mp4, FPS: 65.63847350853787
# Processed shop_lifter_n_133.mp4, FPS: 73.345538828262
# Processed shop_lifter_n_144.mp4, FPS: 63.65363814897184
# Processed shop_lifter_n_160.mp4, FPS: 74.66821760220151
# Processed shop_lifter_n_157.mp4, FPS: 60.981258951217754
# Processed shop_lifter_n_145.mp4, FPS: 72.84898311186308
# Processed shop_lifter_n_156.mp4, FPS: 72.74322859749809
# Processed shop_lifter_n_154.mp4, FPS: 64.43011963682794
# Processed shop_lifter_n_150.mp4, FPS: 62.810326263565614
# Processed shop_lifter_n_116.mp4, FPS: 74.00722811531615
# Processed shop_lifter_n_134.mp4, FPS: 64.38740910581366
# Processed shop_lifter_n_137.mp4, FPS: 69.3499650697898
# Processed shop_lifter_n_132.mp4, FPS: 67.05635745209803
# Processed shop_lifter_n_129.mp4, FPS: 65.11196645744172
# Processed shop_lifter_n_118.mp4, FPS: 72.89735739293172
# Processed shop_lifter_n_146.mp4, FPS: 70.0152707027528
# Processed shop_lifter_n_122.mp4, FPS: 57.59741964684932
# Processed shop_lifter_n_143.mp4, FPS: 73.4334046861473
# Processed shop_lifter_n_58.mp4, FPS: 75.05468701044495
# Processed shop_lifter_n_76.mp4, FPS: 63.767052155205114
# Processed shop_lifter_n_93.mp4, FPS: 72.55307493763898
# Processed shop_lifter_n_112.mp4, FPS: 70.1582162196448
# Processed shop_lifter_n_91.mp4, FPS: 60.69434326676549
# Processed shop_lifter_n_81.mp4, FPS: 73.41839805688154
# Processed shop_lifter_n_114.mp4, FPS: 60.04450296419201
# Processed shop_lifter_n_86.mp4, FPS: 73.10394927922708
# Processed shop_lifter_n_82.mp4, FPS: 74.15644756602138
# Processed shop_lifter_n_60.mp4, FPS: 58.43420769779361
# Processed shop_lifter_n_62.mp4, FPS: 68.93871440753053
# Processed shop_lifter_n_110.mp4, FPS: 74.26558837010003
# Processed shop_lifter_n_59.mp4, FPS: 74.63134538427731
# Processed shop_lifter_n_106.mp4, FPS: 58.389488254380815
# Processed shop_lifter_n_95.mp4, FPS: 75.12291298031933
# Processed shop_lifter_n_113.mp4, FPS: 73.05718210480288
# Processed shop_lifter_n_57.mp4, FPS: 60.81370906695971
# Processed shop_lifter_n_89.mp4, FPS: 68.68947163126272
# Processed shop_lifter_n_66.mp4, FPS: 69.027864249273
# Processed shop_lifter_n_61.mp4, FPS: 66.18344329445088
# Processed shop_lifter_n_77.mp4, FPS: 71.76917530292644
# Processed shop_lifter_n_102.mp4, FPS: 58.41601097018095
# Processed shop_lifter_n_50.mp4, FPS: 72.15871623846182
# Processed shop_lifter_n_63.mp4, FPS: 60.21792641294821
# Processed shop_lifter_n_55.mp4, FPS: 73.52240281876668
# Processed shop_lifter_n_101.mp4, FPS: 72.10975016831266
# Processed shop_lifter_n_52.mp4, FPS: 64.35864954027676
# Processed shop_lifter_n_69.mp4, FPS: 74.30598362015756
# Processed shop_lifter_n_84.mp4, FPS: 53.94798422716775
# Processed shop_lifter_n_83.mp4, FPS: 75.02548453321626
# Processed shop_lifter_n_108.mp4, FPS: 74.74006810820238
# Processed shop_lifter_n_49.mp4, FPS: 61.933058818778235
# Processed shop_lifter_n_98.mp4, FPS: 73.0171967771323
# Processed shop_lifter_n_74.mp4, FPS: 74.59792250773137
# Processed shop_lifter_n_90.mp4, FPS: 58.70235308680526
# Processed shop_lifter_n_80.mp4, FPS: 71.48402333149208
# Processed shop_lifter_n_67.mp4, FPS: 63.85560683917076
# Processed shop_lifter_n_65.mp4, FPS: 73.57547746041614
# Processed shop_lifter_n_64.mp4, FPS: 75.17164651192577
# Processed shop_lifter_n_104.mp4, FPS: 61.9380805008423
# Processed shop_lifter_n_92.mp4, FPS: 73.13822358286781
# Processed shop_lifter_n_72.mp4, FPS: 62.88434197753506
# Processed shop_lifter_n_71.mp4, FPS: 72.84147338728462
# Processed shop_lifter_n_103.mp4, FPS: 68.47190813135134
# Processed shop_lifter_n_53.mp4, FPS: 62.88163517582194
# Processed shop_lifter_n_96.mp4, FPS: 74.46654993392593
# Processed shop_lifter_n_94.mp4, FPS: 66.20561113710023
# Processed shop_lifter_n_87.mp4, FPS: 64.14276306138895
# Processed shop_lifter_n_68.mp4, FPS: 75.35615509522682
# Processed shop_lifter_n_88.mp4, FPS: 58.57090445334611
# Processed shop_lifter_n_54.mp4, FPS: 73.21923784193123
# Processed shop_lifter_n_100.mp4, FPS: 72.03671407752394
# Processed shop_lifter_n_73.mp4, FPS: 63.82746318035128
# Processed shop_lifter_n_111.mp4, FPS: 73.24862210362339
# Processed shop_lifter_n_78.mp4, FPS: 63.09829803733151
# Processed shop_lifter_n_97.mp4, FPS: 73.98483720634876
# Processed shop_lifter_n_79.mp4, FPS: 61.50802523298472
# Processed shop_lifter_n_47.mp4, FPS: 74.59537015453607
# Processed shop_lifter_n_51.mp4, FPS: 59.6413910424384
# Processed shop_lifter_n_105.mp4, FPS: 73.73111262594779
# Processed shop_lifter_n_48.mp4, FPS: 74.39409215372918
# Processed shop_lifter_n_109.mp4, FPS: 57.650547327119035
# Processed shop_lifter_n_85.mp4, FPS: 74.80720349122542
# Processed shop_lifter_n_75.mp4, FPS: 75.6914407784248
# Processed shop_lifter_n_9.mp4, FPS: 60.12131006044333
# Processed shop_lifter_n_19.mp4, FPS: 73.87338183876734
# Processed shop_lifter_n_28.mp4, FPS: 72.76556848239166
# Processed shop_lifter_n_42.mp4, FPS: 65.22852496366968
# Processed shop_lifter_n_2.mp4, FPS: 73.70605384528955
# Processed shop_lifter_n_11.mp4, FPS: 63.82904701683988
# Processed shop_lifter_n_40.mp4, FPS: 72.69698050648569
# Processed shop_lifter_n_12.mp4, FPS: 64.54459998675038
# Processed shop_lifter_n_1.mp4, FPS: 74.08255738332666
# Processed shop_lifter_n_4.mp4, FPS: 61.37113128226909
# Processed shop_lifter_n_8.mp4, FPS: 73.3228568458376
# Processed shop_lifter_n_20.mp4, FPS: 63.84588189539385
# Processed shop_lifter_n_25.mp4, FPS: 72.05742185755173
# Processed shop_lifter_n_29.mp4, FPS: 65.63676735533757
# Processed shop_lifter_n_6.mp4, FPS: 66.04978736352383
# Processed shop_lifter_n_41.mp4, FPS: 73.57332537545396
# Processed shop_lifter_n_13.mp4, FPS: 67.33963817762807
# Processed shop_lifter_n_21.mp4, FPS: 64.73614447492204
# Processed shop_lifter_n_37.mp4, FPS: 72.98537487972055
# Processed shop_lifter_n_44.mp4, FPS: 68.63497268409348
# Processed shop_lifter_n_30.mp4, FPS: 58.831843962949364
# Processed shop_lifter_n_7.mp4, FPS: 73.4540622565719
# Processed shop_lifter_n_34.mp4, FPS: 61.32291395659046
# Processed shop_lifter_n_31.mp4, FPS: 71.37001864946852
# Processed shop_lifter_n_10.mp4, FPS: 67.74154665711715
# Processed shop_lifter_n_27.mp4, FPS: 64.5639146047875
# Processed shop_lifter_n_17.mp4, FPS: 74.51741390513551
# Processed shop_lifter_n_39.mp4, FPS: 59.17432545241306
# Processed shop_lifter_n_22.mp4, FPS: 72.93078175992385
# Processed shop_lifter_n_45.mp4, FPS: 63.52131432399653
# Processed shop_lifter_n_32.mp4, FPS: 69.48905269439818
# Processed shop_lifter_n_36.mp4, FPS: 64.97250409251113
